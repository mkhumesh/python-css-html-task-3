# %%
from urllib.request import urlopen

# %%
url ='https://jovian.com/singhalkshama4343/web-scraping-project'

# %%
resp = urlopen(url)

# %%
resp.status
# Out:
# 200

# %%
data=resp.read()

# %%
data
# Out:
# b'<!DOCTYPE html><html lang="en"><head><meta charSet="utf-8"/><link rel="shortcut icon" href="/jovian_favicon.png"/><title>Web Scraping Project - Notebook by Kshama Singhal (singhalkshama4343) | Jovian </title><meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"/><meta name="description" content="Collaborate with singhalkshama4343 on web-scraping-project notebook."/><meta property="og:title" content="Web Scraping Project - Notebook by Kshama Singhal (singhalkshama4343) | Jovian "/><meta property="og:description" content="Collaborate with singhalkshama4343 on web-scraping-project notebook."/><meta property="og:image" content="https://api.jovian.com/api/gist/88955ecee0f842c09b6c8bf651869dac/preview/449505b39e24418ea68bc7dc4ba8e157?ts=1665117926258"/><meta property="og:image:width" content="1200"/><meta property="og:image:height" content="628"/><meta property="og:type" content="article"/><meta property="og:sitename" content="Jovian"/><meta property="og:u
# ...

# %%
web=data.decode("utf-8")

# %%
print(web)
# Out:
# <!DOCTYPE html><html lang="en"><head><meta charSet="utf-8"/><link rel="shortcut icon" href="/jovian_favicon.png"/><title>Web Scraping Project - Notebook by Kshama Singhal (singhalkshama4343) | Jovian </title><meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"/><meta name="description" content="Collaborate with singhalkshama4343 on web-scraping-project notebook."/><meta property="og:title" content="Web Scraping Project - Notebook by Kshama Singhal (singhalkshama4343) | Jovian "/><meta property="og:description" content="Collaborate with singhalkshama4343 on web-scraping-project notebook."/><meta property="og:image" content="https://api.jovian.com/api/gist/88955ecee0f842c09b6c8bf651869dac/preview/449505b39e24418ea68bc7dc4ba8e157?ts=1665117926258"/><meta property="og:image:width" content="1200"/><meta property="og:image:height" content="628"/><meta property="og:type" content="article"/><meta property="og:sitename" content="Jovian"/><meta property="og:url
# ...
